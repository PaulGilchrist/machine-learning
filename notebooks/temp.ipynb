# %%
import pandas as pd

# %%
#input_df = pd.read_csv('~/downloads/Zillow_Home_Values_By_Zip.csv')
input_df = pd.read_csv('~/downloads/ACSST1Y2021.S0802-2023-03-13T160952.csv')
input_df.head()
# Out:
#             Label (Grouping) United States!!Total!!Estimate  \
# 0  Workers 16 years and over                    154,314,179
# 1                        AGE                            NaN
# 2             16 to 19 years                           3.8%
# 3             20 to 24 years                           9.1%
# 4             25 to 44 years                          44.0%
#
#   United States!!Total!!Margin of Error  \
# 0                              ±151,398
# 1                                   NaN
# 2                                  ±0.1
# 3                                  ±0.1
# 4                                  ±0.1
#
#   United States!!Car, truck, or van -- drove alone!!Estimate  \
# 0                                        104,650,121
# 1                                                NaN
# 2                                               3.6%
# 3                                               9.3%
# 4                                              43.0%
#
# ...
